# %% [markdown]
# ## Load fill and beam modes

# %%
# %pylab notebook
import pytimber
import datetime
import pickle
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
mdb=pytimber.LoggingDB(source='mdb')

output_path='./'
tag='TDI_fullscan'

beam=1

ts1 = '2016-04-09 10:30:00' # start time
ts2 = '2016-04-09 10:50:00' # end time

# %%
# BCT
import LHC_BCT
reload(LHC_BCT)

# data=mdb.get(LHC_BCT.variable_list(beams=[beam]),ts1,ts2)
# pickle.dump( data, open( output_path+"BCT"+tag+"_B%d.pkl"%beam, "wb" ) )
data = pickle.load( open( output_path+"BCT"+tag+"_B%d.pkl"%beam, "rb" ) )

BCT=LHC_BCT.BCT(data,beam=beam)

# %%
# BBQ

import LHC_BBQ
reload(LHC_BBQ)

# data=mdb.get(LHC_BBQ.variable_list(beams=[beam]),ts1,ts2)
# pickle.dump( data, open( output_path+"BBQ"+tag+"_B%d.pkl"%beam, "wb" ) )
data = pickle.load( open( output_path+"BBQ"+tag+"_B%d.pkl"%beam, "rb" ) )
BBQ=LHC_BBQ.BBQ(data,beam=beam)

figure()
plot(BBQ.t_str, BBQ.amp_1, "-k")
plot(BBQ.t_str, BBQ.amp_2, "-r")
xlabel("Time")
ylabel("BBQ amp1")
title('B%d'%(BBQ.beam))
legend(['amp1','amp2'])
xfmt = mpl.dates.DateFormatter('%H:%M:%S')
gca().xaxis.set_major_formatter(xfmt)
# Out:
# <img src="data:image/png;base64,...">

# %%
# BBQ FFT
import LHC_BBQ

# BBQ
# data=mdb.get(LHC_BBQ.variable_list(beams=[beam]),ts1,ts2)
# data = pickle.load( open( output_path+"BBQ"+tag+"_B%d.pkl"%beam, "rb" ) )
BBQ_FFT=LHC_BBQ.BBQ_FFT(data,beam=beam)

figure()
plot( (BBQ_FFT.fft_h[0]), "-" )
plot( (BBQ_FFT.fft_v[0]), "-r" )
title(BBQ_FFT.t_str[0])

# Waterfall
figure()
mindate = mpl.dates.date2num(BBQ_FFT.t_str[0])
maxdate = mpl.dates.date2num(BBQ_FFT.t_str[-1])
img = plt.imshow(BBQ_FFT.fft_v, origin='lower', cmap='jet', interpolation='nearest', aspect='auto',
                extent=(0, 0.5, mindate, maxdate))

hfmt = DateFormatter('%H:%M:%S')
gca().yaxis.set_major_formatter(hfmt)

title('B%d BBQ-FFT: '%BBQ_FFT.beam +
    str(BBQ_FFT.t_str[0].strftime('%d/%m/%y %H:%M:%S')) +'->'+
      str(BBQ_FFT.t_str[-1].strftime('%d/%m/%y %H:%M:%S')))

xlim(0.25, 0.35)
# Out:
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# (0.25, 0.35)

# %%
# RAW BBQ
import LHC_BBQ
reload(LHC_BBQ)

# data=mdb.get(LHC_BBQ.variable_list_RAW(beams=[beam]),ts1,ts2)
# pickle.dump( data, open( output_path+"BBQ_RAW"+tag+"_B%d.pkl"%beam, "wb" ) )
data = pickle.load( open( output_path+"BBQ_RAW"+tag+"_B%d.pkl"%beam, "rb" ) )

BBQ_RAW=LHC_BBQ.BBQ_RAW(data,beam=beam)

figure()
plot((BBQ_RAW.HS_h[0]), "-" )
# Out:
# <img src="data:image/png;base64,...">

# %%
# Collimators

import LHC_Coll
reload(LHC_Coll)

# data=mdb.get(LHC_Coll.variable_list(beam),ts1,ts2)
# pickle.dump( data, open( output_path+"Coll"+tag+"_B%d.pkl"%beam, "wb" ) )
data = pickle.load( open( output_path+"Coll"+tag+"_B%d.pkl"%beam, "rb" ) )

TDI2=LHC_Coll.Coll(data,beam=beam)
TDI2.select_coll('TDI.4L2:MEAS_LVDT_GU')

figure()
plot(TDI2.t_str, TDI2.values, "-b")
xlabel("Time")
ylabel("Collimator gap")
title('B%d'%(TDI2.beam))
xfmt = mpl.dates.DateFormatter('%H:%M')
gca().xaxis.set_major_formatter(xfmt)
# Out:
# <img src="data:image/png;base64,...">

# %%
# fig, ax1 = plt.subplots()
# t = np.arange(0.01, 10.0, 0.01)
# s1 = np.exp(t)
# ax1.plot(TDI2.t_str, TDI2.values, 'b-')
# ax1.set_xlabel('time')
# # Make the y-axis label and tick labels match the line color.
# ax1.set_ylabel('TDI', color='b')
# for tl in ax1.get_yticklabels():
#     tl.set_color('b')
# xfmt = mpl.dates.DateFormatter('%H:%M')
# ax1.xaxis.set_major_formatter(xfmt)

# ax2 = ax1.twinx()
# ax2.plot(BBQ.t_str, BBQ.qv, 'k.')
# ax2.set_ylabel('BBQ', color='k')
# for tl in ax2.get_yticklabels():
#     tl.set_color('k')

# %% [markdown]
# ### Clean uncorrelated noise with SVD cut

# %%
U, s, V = np.linalg.svd(BBQ_RAW.HS_v, full_matrices=False)
s[10:-1]=0
BBQ_RAW.HS_v=np.dot(U,np.dot(np.diag(s),V))

U, s, V = np.linalg.svd(BBQ_RAW.HS_h, full_matrices=False)
s[10:-1]=0
BBQ_RAW.HS_h=np.dot(U,np.dot(np.diag(s),V))

figure()
subplot(2,1,1)
semilogx(s)

subplot(2,1,2)
plot(BBQ_RAW.HS_v[0],'-r')
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ###  Sussix

# %%
import PySUSSIX as ps

# Sussix it!
tuney_vec=[];tunex_vec=[];
for ii in np.arange(0,len(BBQ_RAW.HS_v)):
    datax=BBQ_RAW.HS_h[ii]
    datay=BBQ_RAW.HS_v[ii]
    spec=ps.Sussix()
    spec.sussix_inp(nt1=1,nt2=2048,tunex=0.275,tuney=0.32,ex=5e-3,ey=5e-3,ir=1,nharm=5)
    spec.sussix(datax,0*datax, 
                datay, 0*datay, 
                0*datax, 0*datay)
    tuney=spec.oy[spec.ay.argmax()]
    tunex=spec.ox[spec.ax.argmax()]
    tunex_vec.append(np.abs(tunex))
    tuney_vec.append(np.abs(tuney))

BBQ_RAW.qh=np.array(tunex_vec)
BBQ_RAW.qv=np.array(tuney_vec)

# plot RAW and spectrum    
# figure()
# subplot(2,2,1)
# plot(BBQ_RAW.HS_h[0])
# spec.ax=spec.ax[spec.ox.argsort()]
# spec.ox.sort()
# subplot(2,2,2)
# stem(spec.ox,spec.ax,'.k')
# xlim(0.2 ,0.3)

# subplot(2,2,3)
# plot(BBQ_RAW.HS_v[0])
# spec.ay=spec.ay[spec.oy.argsort()]
# spec.oy.sort()
# subplot(2,2,4)
# stem(spec.oy,spec.ay,'.k')
# xlim(0.2 ,0.4)

# # plot tunes
# figure()
# subplot(2,1,1)
# plot(BBQ_RAW.qh)
# ylabel('Qx')
# ylim(0.2 ,0.3)
# subplot(2,1,2)
# plot(BBQ_RAW.qv)
# ylabel('Qy')
# ylim(0.3 ,0.32)

# %%
# fig, ax1 = plt.subplots()
# ax1.plot(TDI2.t_str, TDI2.values, 'b-')
# ax1.set_xlabel('time')
# ax1.set_ylabel('TDI full gap [mm]', color='b')
# for tl in ax1.get_yticklabels():
#     tl.set_color('b')
# xfmt = mpl.dates.DateFormatter('%H:%M')
# ax1.xaxis.set_major_formatter(xfmt)

# ax2 = ax1.twinx()
# ax2.plot(BBQ.t_str, BBQ.qv, 'ok',alpha=0.2,markerfacecolor='k',markeredgecolor='k')
# ax2.plot(BBQ_RAW.t_str, BBQ_RAW.qv,  'or',alpha=0.2,markerfacecolor='r',markeredgecolor='r')
# ax2.set_ylabel('Tune', color='k')
# for tl in ax2.get_yticklabels():
#     tl.set_color('k')
# ylim(0.305, 0.312)

# %% [markdown]
# ### Moving average

# %%
N=100;

BBQ_RAW.qv=np.convolve(np.ravel(BBQ_RAW.qv), np.ones((N,))/N,mode='same')
BBQ.qv=np.convolve(np.ravel(BBQ.qv), np.ones((N,))/N,mode='same')
TDI2.values=np.convolve(TDI2.values, np.ones((N,))/N,mode='same')

fig, ax1 = plt.subplots()
ax1.plot(TDI2.t_str, TDI2.values, 'b-')
ax1.set_xlabel('time')
ax1.set_ylabel('TDI', color='b')
for tl in ax1.get_yticklabels():
    tl.set_color('b')
xfmt = mpl.dates.DateFormatter('%H:%M')
ax1.xaxis.set_major_formatter(xfmt)

ax2 = ax1.twinx()
ax2.plot(BBQ.t_str, BBQ.qv, 'ok',alpha=0.1,markerfacecolor='k',markeredgecolor='k')
ax2.plot(BBQ_RAW.t_str, BBQ_RAW.qv, 'r.')
ax2.set_ylabel('BBQ', color='k')
for tl in ax2.get_yticklabels():
    tl.set_color('k')
ylim(0.308, 0.3116)
# Out:
# <img src="data:image/png;base64,...">
# (0.308, 0.3116)

# %%
gu=94;
gd=4.992

TDI2.interp_with(BBQ)
BBQ.interp_with(TDI2)
BBQ_RAW.interp_with(TDI2)



mask=(TDI2.values>gu) #| (TDI2.values<gd)

fig, ax1 = plt.subplots()
ax1.plot(TDI2.t_str, TDI2.values, 'b-')
ax1.set_xlabel('time')
ax1.set_ylabel('TDI', color='b')
for tl in ax1.get_yticklabels():
    tl.set_color('b')
xfmt = mpl.dates.DateFormatter('%H:%M')
ax1.xaxis.set_major_formatter(xfmt)

ax2 = ax1.twinx()
ax2.plot(np.array(BBQ.t_str)[mask], BBQ.qv[mask], 'ok',alpha=0.1,markerfacecolor='k',markeredgecolor='k')
ax2.plot(np.array(BBQ_RAW.t_str)[mask], BBQ_RAW.qv[mask], 'r.')
ax2.set_ylabel('BBQ', color='k')
for tl in ax2.get_yticklabels():
    tl.set_color('k')
ylim(0.308, 0.3116)
# Out:
# (1200,)
# (8690,)
# <img src="data:image/png;base64,...">
# (0.308, 0.3116)

# %%
# Out:
# [ True  True  True ..., False False False]

# %%
x=BBQ.t_stamps
y=BBQ.qv

mask_tune=(y<0.31) & (y>0.3)

p=np.polyfit(x[mask_tune],y[mask_tune],1)
slope=p[0]
intercept=p[1]

fit=slope*x+intercept


mask1=(TDI2.values>gu) 

x=BBQ.t_stamps[mask1]
y=BBQ.qv[mask1]
fit1=fit[mask1]

mask_tune=(y<0.31) & (y>0.3)

y1=y-fit1
y1_mean=np.mean(y1[mask_tune])
y1_std=np.std(y1[mask_tune])

print mean(y1[mask_tune])


mask2=(TDI2.values<gd) 

x=BBQ.t_stamps[mask2]
y=BBQ.qv[mask2]

fit2=fit[mask2]

mask_tune=(y<0.31) & (y>0.307)

y2=y-fit2
y2_mean=np.mean(y2[mask_tune])
y2_std=np.std(y2[mask_tune])

figure()
plot(y)
print y2_mean

fig, ax1 = plt.subplots()
ax1.plot(TDI2.t_str, TDI2.values, 'b-')
ax1.set_xlabel('time')
ax1.set_ylabel('TDI', color='b')
for tl in ax1.get_yticklabels():
    tl.set_color('b')
xfmt = mpl.dates.DateFormatter('%H:%M')
ax1.xaxis.set_major_formatter(xfmt)

ax2 = ax1.twinx()
ax2.plot(np.array(BBQ.t_str)[mask1], y1, 'ok',alpha=0.1,markerfacecolor='k',markeredgecolor='k')
ax2.plot(np.array(BBQ.t_str)[mask2][mask_tune], y2[mask_tune], 'ok',alpha=.1,markerfacecolor='k',markeredgecolor='k')
# ax2.plot(np.array(BBQ.t_str)[mask], y2, 'ok',alpha=0.1,markerfacecolor='k',markeredgecolor='k')
# ax2.plot(np.array(BBQ_RAW.t_str)[mask], BBQ_RAW.qv[mask], 'r.')
# ax2.plot(np.array(BBQ.t_str),slope*BBQ.t_stamps+intercept)
# ax2.set_ylabel('BBQ', color='k')
# for tl in ax2.get_yticklabels():
#     tl.set_color('k')
# ylim(0.308, 0.3116)

ts_mean=y1_mean- y2_mean
ts_std=y1_std+y2_std

print '%.1e+/-%.1e'%(y1_mean,y1_std)
print '%.1e+/-%.1e'%(y2_mean,y2_std)
print 'tune shift: %.1e+/-%.1e'%(ts_mean,ts_std)
# Out:
# 4.43315046095e-05
# <img src="data:image/png;base64,...">
# -7.07308641682e-05
# <img src="data:image/png;base64,...">
# 4.4e-05+/-5.1e-05
# -7.1e-05+/-4.8e-05
# tune shift: 1.2e-04+/-9.9e-05

# %%
# %pylab notebook
import sys, os
import pickle
import glob

pyDir='/home/nick/HDD/Work/Python-scripts/LHCMeasurementTools/'
sys.path.append(pyDir)
pyDir='/home/nick/HDD/Work/Python-scripts/PySUSSIX'
sys.path.append(pyDir)
pyDir='/home/nick/HDD/Work/Python-scripts/rdmstores/cernlogdb/'
sys.path.append(pyDir)

import TimberManager as tm
import LHC_Fills
import TimestampHelpers as th
import numpy as np
import lhc_log_db_query as lldb
import PySUSSIX as ps
import cernlogdb as cl 

from plotly.offline import download_plotlyjs, init_notebook_mode, iplot
init_notebook_mode()
import plotly.graph_objs as go

import datetime

# %%
# get fill numbers
t_start_string = '2016-04-12 02:35:10'
t_stop_string = '2016-04-17 02:35:40'

filename = 'fills_and_bmodes'
csv_name = filename + '.csv'
pkl_name = filename + '.pkl'
varlist=LHC_Fills.get_varlist()
tm.dbquery(varlist=varlist, t_start=t_start_string, t_stop=t_stop_string, step=None,filename = csv_name)
LHC_Fills.make_pickle(csv_name, pkl_name,t_stop_string)

# %%
import LHC_BBQ, LHC_BCT, LHC_Energy, LHC_Coll, LHC_BSRT

beam=2

# %%
# Energy
filename=fillstr+'_Energy_B%d.csv'%beam
variable_list=LHC_Energy.variable_list()
tm.dbquery(variable_list,time_start,time_end,step=None,filename=filename)
Energy=LHC_Energy.energy(filename,beam=beam)

# %%
# BSRT
filename=fillstr+'_BSRT_B%d.csv'%beam
variable_list=LHC_BSRT.variable_list()
tm.dbquery(variable_list,time_start,time_end,step='5 MINUTE',filename=filename)


files=glob.glob('*'+filename.replace('.csv','')+'*')
files.sort(key=os.path.getmtime)
data=cl.merge_out(variable_list,[file(ff) for ff in files])
for key in data.keys():
    newshape=np.shape(data[key].values)[-1]
    data[key].values=(np.reshape(data[key].values,[-1,newshape]))
BSRT=LHC_BSRT.BSRT(data,beam=beam)

# LHC_BSRT.Masked?
# BSRT.calculate_emittances(Energy)

# bunchid=BSRT.bunch_n[0]
# BSRT.int_norm_emit_h=np.interp(BSRT.t_stamps[BSRT.bunch_n==bunchid],BSRT.t_stamps,BSRT.norm_emit_h)
# BSRT.int_norm_emit_v=np.interp(BSRT.t_stamps[BSRT.bunch_n==bunchid],BSRT.t_stamps,BSRT.norm_emit_v)

# %%
freq=np.linspace(0,0.5,num=len(BBQ_FFT.fft_v.values[0]))
figure(3)
plot(freq,BBQ_FFT.fft_v.values[0])
plot()

# %%
gap_vec=np.ravel(np.array(Coll.values,float))
indgap=[(gap_vec<6) | (gap_vec>95)]

tvals=np.ravel(np.array(Coll.t_stamps,float))
xp=tvals[indgap]

np.all(np.diff(xp) >= 0)
# np.argwhere(np.isnan(tuney_vec))
yp=np.interp(BBQ_RAW.t_stamps[10],BBQ_RAW.t_stamps[1:11101],tuney_vec[1:11101])
print yp
print tuney_vec[10]
# np.diff(yp)
# np.interp?
# BBQ_RAW.t_stamps

# figure(5)

# plot(BBQ_RAW.t_stamps,tuney_vec,'.r')
# plot(xp,yp,'.k')
# indup=[]

# %%
Coll.select_coll('TDI.4R8:MEAS_LVDT_GU')
Coll.t_str=[datetime.datetime.fromtimestamp(Coll.t_stamps[ii]) for ii in np.arange(len(Coll.t_stamps))]

N=30;
tuney_av_vec=np.convolve(np.ravel(BBQ_FFT.tune_v.values), np.ones((N,))/N, mode='valid')
tuney_av_vec2=np.convolve(tuney_vec, np.ones((N,))/N, mode='valid')
gap_av_vec=np.convolve(np.squeeze(np.array(Coll.values,dtype=float)), np.ones((N,))/N, mode='valid')

trace1 = go.Scatter(
    x=(BBQ_FFT.t_str),
    y=tuney_av_vec,
    name='BBQ',
)

trace2 = go.Scatter(
    x=(Coll.t_str),
    y=gap_av_vec,
    name='Coll',
    yaxis='y2'
)

trace3 = go.Scatter(
    x=(BBQ_RAW.t_str),
    y=tuney_av_vec2,
    name='Sussix',
    yaxis='y'
)

data = [trace1, trace2,trace3]
layout = go.Layout(
    title='B%d'%beam,
    width=1000,
    xaxis=dict(
        domain=[0.1, 0.8]
    ),
    yaxis=dict(
        title='Qy',
        titlefont=dict(
            color='#1f77b4'
        ),
        tickfont=dict(
            color='#1f77b4'
        ),
        exponentformat='e',
        position=0.05,
        side='left',
        range=[0.305, 0.312],
    ),
    yaxis2=dict(
        title='TDI full gap [mm]',
        titlefont=dict(
            color='#ff7f0e'
        ),
        tickfont=dict(
            color='#ff7f0e'
        ),
        anchor='x',
        overlaying='y',
        side='right',
        position=1.2,
        exponentformat='e',
    )
)

fig = go.Figure(data=data, layout=layout)
iplot(fig)

# %%
import pytimber

mdb = pytimber.LoggingDB(source='mdb')

# %%
filename='fill%d_BSRT'%filln
variable_list=LHC_BSRT.variable_list()

d=mdb.get(variable_list,t_start_string,t_stop_string)
f = h5py.File(output_path + '/filename.h5','w')
f.create_dataset('horizontal', data=np.concatenate(d[var][1]))

# %%
# BSRT
filename='fill%d_BSRT.csv'%filln
variable_list=LHC_BSRT.variable_list()
# tm.dbquery(variable_list,time_start,time_end,filename=filename)
BSRT=LHC_BSRT.BSRT(filename,beam=beam)
LHC_BSRT.Masked?
BSRT.calculate_emittances(Energy)

bunchid=BSRT.bunch_n[0]
BSRT.int_norm_emit_h=np.interp(BSRT.t_stamps[BSRT.bunch_n==bunchid],BSRT.t_stamps,BSRT.norm_emit_h)
BSRT.int_norm_emit_v=np.interp(BSRT.t_stamps[BSRT.bunch_n==bunchid],BSRT.t_stamps,BSRT.norm_emit_v)

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, iplot
init_notebook_mode()
import plotly.graph_objs as go

import datetime

BBQ.t_str=[datetime.datetime.fromtimestamp(BBQ.t_stamps[ii]) for ii in np.arange(len(BBQ.t_stamps))]
BBQ_FFT.t_str=[datetime.datetime.fromtimestamp(BBQ_FFT.t_stamps[ii]) for ii in np.arange(len(BBQ_FFT.t_stamps))]
BCT.t_str=[datetime.datetime.fromtimestamp(BCT.t_stamps[ii]) for ii in np.arange(len(BCT.t_stamps))]
Energy.t_str=[datetime.datetime.fromtimestamp(Energy.t_stamps[ii]) for ii in np.arange(len(Energy.t_stamps))]
BSRT.t_str=[datetime.datetime.fromtimestamp(BSRT.t_stamps[BSRT.bunch_n==1785][ii]) for ii in np.arange(len(BSRT.t_stamps[BSRT.bunch_n==1785]))]

# %%
beam=1



BBQ.t_str=[datetime.datetime.fromtimestamp(BBQ.t_stamps[ii]) for ii in np.arange(len(BBQ.t_stamps))]
BBQ_FFT.t_str=[datetime.datetime.fromtimestamp(BBQ_FFT.t_stamps[ii]) for ii in np.arange(len(BBQ_FFT.t_stamps))]
BCT.t_str=[datetime.datetime.fromtimestamp(BCT.t_stamps[ii]) for ii in np.arange(len(BCT.t_stamps))]
Energy.t_str=[datetime.datetime.fromtimestamp(Energy.t_stamps[ii]) for ii in np.arange(len(Energy.t_stamps))]
BSRT.t_str=[datetime.datetime.fromtimestamp(BSRT.t_stamps[BSRT.bunch_n==1785][ii]) for ii in np.arange(len(BSRT.t_stamps[BSRT.bunch_n==1785]))]

trace1 = go.Scatter(
    x=(BSRT_B1.t_str),
    y=BSRT_B1.sigma_h,
    name='BSRT'
)
trace2 = go.Scatter(
    x=(Energy.t_str),
    y=Energy.energy,
    name='Energy',
    yaxis='y2'
)
trace3 = go.Scatter(
    x=(BBQ_B1.t_str),
    y=BBQ_B1.xamp_1,
    name='BBQ',
    yaxis='y3'
)
data = [trace1, trace2, trace3]
layout = go.Layout(
    title='B%d'%beam,
    width=1000,
    xaxis=dict(
        domain=[0.1, 0.9]
    ),
    yaxis=dict(
        title='BSRT',
        titlefont=dict(
            color='#1f77b4'
        ),
        tickfont=dict(
            color='#1f77b4'
        ),
        exponentformat='e',
        position=0.05,
    ),
    yaxis2=dict(
        title='Energy',
        titlefont=dict(
            color='#ff7f0e'
        ),
        tickfont=dict(
            color='#ff7f0e'
        ),
        anchor='free',
        overlaying='y',
        side='left',
        exponentformat='e',
        position=0.15
    ),
    yaxis3=dict(
        title='BBQ',
        titlefont=dict(
            color='#d62728'
        ),
        tickfont=dict(
            color='#d62728'
        ),
        anchor='x',
        overlaying='y',
        side='right'
    ),
)

fig = go.Figure(data=data, layout=layout)
iplot(fig)
